# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
url='https://www.google.com/url?sa=D&q=https://drive.google.com/file/d/1pP0Rr83ri0voscgr95-YnVCBv6BYV22w/view&ust=1654840560000000&usg=AOvVaw3DOOYUiUrbWKmjffcv4cYO&hl=en-GB'

# %%
pd.read_csv(url)
# Out:
#                                         <HTML><HEAD>
# 0  <meta http-equiv="content-type" content="text/...
# 1                         <TITLE>Redirecting</TITLE>
# 2  <META HTTP-EQUIV="refresh" content="1; url=htt...
# 3                                            </HEAD>
# 4  <BODY onLoad="location.replace('https://drive....
# 5  Redirecting you to https://drive.google.com/fi...

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Chinmay\\Downloads\\Py-DS-ML-Bootcamp-master\\Refactored_Py_DS_ML_Bootcamp-master'

# %%
df=pd.read_csv('data_stocks (1).csv')

# %%
df.head()
# Out:
#          DATE      SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  \
# 0  1491226200  2363.6101     42.3300     143.6800     129.6300      82.040
# 1  1491226260  2364.1001     42.3600     143.7000     130.3200      82.080
# 2  1491226320  2362.6799     42.3100     143.6901     130.2250      82.030
# 3  1491226380  2364.3101     42.3700     143.6400     130.0729      82.000
# 4  1491226440  2364.8501     42.5378     143.6600     129.8800      82.035
#
#    NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  NASDAQ.ALXN  ...  NYSE.WYN  NYSE.XEC  \
# 0    102.2300      85.2200       59.760       121.52  ...    84.370   119.035
# 1    102.1400      85.6500       59.840       121.48  ...    84.370   119.035
# 2    102.2125      85.5100       59.795       121.93  ...    84.585   119.260
# 3    102.1400      85.4872       59.620       121.44  ...    84.460   119.260
# 4    102.0600      85.7001       59.620       121.60  ...    84.470   119.610
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41266 entries, 0 to 41265
# Columns: 502 entries, DATE to NYSE.ZTS
# dtypes: float64(501), int64(1)
# memory usage: 158.0 MB

# %%
import seaborn as sns

# %%
df.describe()
# Out:
#                DATE         SP500    NASDAQ.AAL   NASDAQ.AAPL  NASDAQ.ADBE  \
# count  4.126600e+04  41266.000000  41266.000000  41266.000000  41266.00000
# mean   1.497749e+09   2421.537882     47.708346    150.453566    141.31793
# std    3.822211e+06     39.557135      3.259377      6.236826      6.91674
# min    1.491226e+09   2329.139900     40.830000    140.160000    128.24000
# 25%    1.494432e+09   2390.860100     44.945400    144.640000    135.19500
# 50%    1.497638e+09   2430.149900     48.360000    149.945000    142.26000
# 75%    1.501090e+09   2448.820100     50.180000    155.065000    147.10000
# max    1.504210e+09   2490.649900     54.475000    164.510000    155.33000
#
#          NASDAQ.ADI    NASDAQ.ADP   NASDAQ.ADSK   NASDAQ.AKAM   NASDAQ.ALXN  \
# count  41266.000000  41266.000000  41266.000000  41266.000000  41266.000000
# mean      79.446873    103.480398    102.998608     50.894352    122.981163
# ...

# %%
df.isnull().sum()
# Out:
# DATE           0
# SP500          0
# NASDAQ.AAL     0
# NASDAQ.AAPL    0
# NASDAQ.ADBE    0
#               ..
# NYSE.XRX       0
# NYSE.XYL       0
# NYSE.YUM       0
# NYSE.ZBH       0
# NYSE.ZTS       0
# Length: 502, dtype: int64

# %%
sns.pairplot(df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5296/4185451203.py in <module>
# ----> 1 sns.pairplot(df)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2094     # Set up the PairGrid
#    2095     grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 2096     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
# ...

# %%
data_cor = df.copy()
data_cor.drop(['DATE','SP500'],inplace=True,axis=1)

# %%
cor = data_cor.corr()

# %%
cor_dt = pd.DataFrame(data=cor.values, columns=cor.index, index = cor.index)
cor_dt.head()
# Out:
#              NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  NASDAQ.ADP  \
# NASDAQ.AAL     1.000000     0.082065     0.542213    0.209446    0.245801
# NASDAQ.AAPL    0.082065     1.000000     0.714578    0.264269    0.265641
# NASDAQ.ADBE    0.542213     0.714578     1.000000    0.259282    0.476496
# NASDAQ.ADI     0.209446     0.264269     0.259282    1.000000   -0.085074
# NASDAQ.ADP     0.245801     0.265641     0.476496   -0.085074    1.000000
#
#              NASDAQ.ADSK  NASDAQ.AKAM  NASDAQ.ALXN  NASDAQ.AMAT  NASDAQ.AMD  \
# NASDAQ.AAL      0.610881    -0.441142     0.009581     0.681863    0.272518
# NASDAQ.AAPL     0.645233    -0.712522     0.326712     0.545541   -0.238091
# NASDAQ.ADBE     0.872353    -0.759604     0.488717     0.733609    0.201821
# NASDAQ.ADI      0.470756    -0.323603    -0.409747     0.504019    0.042083
# NASDAQ.ADP      0.325630    -0.229119     0.572143     0.099934    0.447506
#
# ...

# %%
df1=cor_dt

# %%
df1[df1['NASDAQ.AAL'].values>0.80][:5]
# Out:
#              NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  NASDAQ.ADP  \
# NASDAQ.AAL     1.000000     0.082065     0.542213    0.209446    0.245801
# NASDAQ.AMZN    0.803319     0.370111     0.730719    0.386619    0.252712
# NASDAQ.EXPE    0.812206     0.379622     0.818384    0.218189    0.369697
# NASDAQ.HAS     0.832713    -0.274890     0.251696    0.252954   -0.030201
# NYSE.CMI       0.810391     0.088336     0.528227    0.206259    0.179664
#
#              NASDAQ.ADSK  NASDAQ.AKAM  NASDAQ.ALXN  NASDAQ.AMAT  NASDAQ.AMD  \
# NASDAQ.AAL      0.610881    -0.441142     0.009581     0.681863    0.272518
# NASDAQ.AMZN     0.828757    -0.648854     0.059345     0.897693    0.170978
# NASDAQ.EXPE     0.834440    -0.707045     0.296553     0.817588    0.199334
# NASDAQ.HAS      0.394658    -0.206013    -0.208923     0.530874    0.258187
# NYSE.CMI        0.577301    -0.458993     0.140823     0.690999    0.184153
#
# ...

# %%
##ANSWER TO FIRST QUESTION IS ABOVE

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=2)

# %%
kmeans.fit(df.drop('DATE',axis=1))
# Out:
# KMeans(n_clusters=2)

# %%
kmeans.cluster_centers_
# Out:
# array([[2445.59029484,   49.36336819,  152.17803629, ...,   74.3559909 ,
#          122.23613015,   62.17402089],
#        [2374.29688289,   44.45774021,  147.06655798, ...,   66.65499994,
#          119.82746944,   56.27505437]])

# %%
def converter(cluster):
    if cluster=='Yes':
        return 1
    else:
        return 0

# %%
df['Cluster'] = df['DATE'].apply(converter)

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(confusion_matrix(df['Cluster'],kmeans.labels_))
print(classification_report(df['Cluster'],kmeans.labels_))
# Out:
# [[27345 13921]
#  [    0     0]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.66      0.80     41266
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.66     41266
#    macro avg       0.50      0.33      0.40     41266
# weighted avg       1.00      0.66      0.80     41266
# C:\Users\Chinmay\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Chinmay\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
from numpy import vstack,array
from numpy.random import rand
import numpy as np
from scipy.cluster.vq import kmeans,vq
import pandas as pd
from math import sqrt
from sklearn.cluster import KMeans
import warnings
warnings.filterwarnings('ignore')

returns = df.pct_change().mean()*252
returns = pd.DataFrame(returns)
returns.columns = ['Returns']
returns.Volatility = df.pct_change().std()*sqrt(252)

# format the data into numpy array to feed into K-means algorithm
dta = np.asarray([np.asarray(returns.Returns), np.asarray(returns.Volatility)]).T

X = df
distortions =[]
for k in range(2,20):
    k_means = KMeans(n_clusters = k)
    k_means.fit(X)
    distortions.append(k_means.inertia_)

fig = plt.figure(figsize=(15,5))
plt.plot(range(2,20),distortions)
plt.grid(True)
plt.title('Elbow-Curve')
plt.show()

# %%
import numpy as np
t = df.copy()
dt=df.drop(['DATE','SP500'],inplace=True,axis=1)

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# convert data into numpy arrays
X = dt.values

# Scaling the values
sc = StandardScaler()
X_scaled = sc.fit_transform(X)

pca = PCA(n_components=150)
pca.fit(X_scaled)

# the amount of variance that each PCA explains
var = pca.explained_variance_ratio_

# cumulative varince explains
var1 = np.cumsum(np.round(var, decimals=4)*100)
print(var1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5296/2252090370.py in <module>
#       1 import numpy as np
#       2 t = df.copy()
# ----> 3 dt=df.drop(['DATE','SP500'],inplace=True,axis=1)
#       4
#       5 from sklearn.decomposition import PCA
#
# AttributeError: 'numpy.ndarray' object has no attribute 'drop'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5296/3376073403.py in <module>
# ----> 1 details = [(name,cluster) for name, cluster in zip(returns.index,idx)]
#       2 details[:5]
#       3 #for detail in details:
#       4 #   print(list(detail))
#
# NameError: name 'idx' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5296/4106970279.py in <module>
# ----> 1 df = pd.DataFrame(details, columns=['Stock_Name','Cluster_No'])
#       2 df.Cluster_No.value_counts()
#
# NameError: name 'details' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5296/4156738843.py in <module>
#       1 # Computing kmeans with K =5 (5 clusters)
# ----> 2 centroids,_= kmeans(dta, 5)
#       3 # Assign each sample to a cluster
#       4 idx,_ = vq(dta, centroids)
#       5
#
# ~\anaconda3\lib\site-packages\scipy\cluster\vq.py in kmeans(obs, k_or_guess, iter, thresh, check_finite, seed)
#     453
#     454     """
# --> 455     obs = _asarray_validated(obs, check_finite=check_finite)
#     456     if iter < 1:
#     457         raise ValueError("iter must be at least 1, got %s" % iter)
#
# ~\anaconda3\lib\site-packages\scipy\_lib\_util.py in _asarray_validated(a, check_finite, sparse_ok, objects_ok, mask_ok, as_inexact)
#     291             raise ValueError('masked arrays are not supported')
# ...
